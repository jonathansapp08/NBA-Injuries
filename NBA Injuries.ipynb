# %%
import numpy as np
import pandas as pd

injuries = pd.read_csv('/Users/jonathansapp/code/notebooks/injuries.csv')

# %%
# Getting rid of entries that say when a player came back to the lineup
injuries = injuries.drop(['Acquired'], axis=1)
injuries = injuries[pd.notnull(injuries['Relinquised'])]

# %%
injuries
# Out:
#             Date          Team                                  Relinquised  \
# 0     2010-10-03         Bulls                                Carlos Boozer
# 1     2010-10-06       Pistons                                Jonas Jerebko
# 2     2010-10-06       Pistons                                Terrico White
# 3     2010-10-08       Blazers                Jeff Pendergraph / Jeff Ayres
# 4     2010-10-08          Nets                                  Troy Murphy
# 5     2010-10-08       Pistons                                Jonas Jerebko
# 6     2010-10-08       Pistons                                Terrico White
# 7     2010-10-09       Nuggets                                Al Harrington
# 8     2010-10-12         Bucks                             Darington Hobson
# 9     2010-10-12         Kings                             Samuel Dalembert
# 10    2010-10-17       Bobcats                              Dominic McGuire
# ...

# %%
injuries["Date"]= pd.to_datetime(injuries["Date"])

# 10-11 Season
# mask = (injuries['Date'] > '2010-11-26') & (injuries['Date'] <= '2011-4-13')
# print(injuries.loc[mask])
# 10-11 Playoffs
# mask = (injuries['Date'] > '2011-4-16') & (injuries['Date'] <= '2011-5-26')
# print(injuries.loc[mask])
# 10-11 Finals
# mask = (injuries['Date'] > '2011-5-31') & (injuries['Date'] <= '2011-6-12')
# print(injuries.loc[mask])

# 11-12 Season
# mask = (injuries['Date'] > '2011-12-25') & (injuries['Date'] <= '2012-4-26')
# print(injuries.loc[mask])
# 11-12 Playoffs
# mask = (injuries['Date'] > '2012-4-28') & (injuries['Date'] <= '2012-6-9')
# print(injuries.loc[mask])
# 11-12 Finals
# mask = (injuries['Date'] > '2013-6-12') & (injuries['Date'] <= '2012-6-21')
# print(injuries.loc[mask])

# 12-13 Season
# mask = (injuries['Date'] > '2012-10-30') & (injuries['Date'] <= '2013-4-17')
# print(injuries.loc[mask])
# 12-13 Playoffs
# mask = (injuries['Date'] > '2013-4-20') & (injuries['Date'] <= '2013-6-3')
# print(injuries.loc[mask])
# 12-13 Finals
# mask = (injuries['Date'] > '2013-6-6') & (injuries['Date'] <= '2013-6-20')
# print(injuries.loc[mask])

# 13-14 Season
# mask = (injuries['Date'] > '2013-10-29') & (injuries['Date'] <= '2014-4-16')
# print(injuries.loc[mask])
# 13-14 Playoffs
# mask = (injuries['Date'] > '2014-4-19') & (injuries['Date'] <= '2014-5-31')
# print(injuries.loc[mask])
# 13-14 Finals
# mask = (injuries['Date'] > '2014-6-5') & (injuries['Date'] <= '2014-6-15')
# print(injuries.loc[mask])

# 14-15 Season
# mask = (injuries['Date'] > '2014-10-28') & (injuries['Date'] <= '2015-4-15')
# print(injuries.loc[mask])
# 14-15 Playoffs
# mask = (injuries['Date'] > '2015-4-18') & (injuries['Date'] <= '2015-5-27')
# print(injuries.loc[mask])
# 14-15 Finals
# mask = (injuries['Date'] > '2015-6-4') & (injuries['Date'] <= '2015-6-16')
# print(injuries.loc[mask])

# 15-16 Season
# mask = (injuries['Date'] > '2015-10-27') & (injuries['Date'] <= '2016-4-13')
# print(injuries.loc[mask])
# 15-16 Playoffs
# mask = (injuries['Date'] > '2016-4-16') & (injuries['Date'] <= '2016-5-30')
# print(injuries.loc[mask])
# 15-16 Finals
# mask = (injuries['Date'] > '2016-6-2') & (injuries['Date'] <= '2016-6-19')
# print(injuries.loc[mask])

# 16-17 Season
# mask = (injuries['Date'] > '2016-10-25') & (injuries['Date'] <= '2017-4-12')
# print(injuries.loc[mask])
# 16-17 Playoffs
# mask = (injuries['Date'] > '2017-4-15') & (injuries['Date'] <= '2017-5-25')
# print(injuries.loc[mask])
# 16-17 Finals
# mask = (injuries['Date'] > '2017-6-1') & (injuries['Date'] <= '2017-6-12')
# print(injuries.loc[mask])

# 17-18 Season
# mask = (injuries['Date'] > '2017-10-17') & (injuries['Date'] <= '2018-4-11')
# print(injuries.loc[mask]) 
# 17-18 Playoffs
# mask = (injuries['Date'] > '2018-4-11') & (injuries['Date'] <= '2018-5-28')
# print(injuries.loc[mask])
# 17-18 Finals
# mask = (injuries['Date'] > '2018-5-31') & (injuries['Date'] <= '2018-6-8')
# print(injuries.loc[mask])

# %%
# Gives you a quick rundown of the injuries
# injuries['Notes'].value_counts()
# injuries.Notes.unique()

# %%
injuries[injuries['Notes'].str.contains("knee")]
# 1636 rows == 1636 knee injuries that took players out
injuries = injuries[~injuries.Notes.str.contains("knee")]

injuries[injuries['Notes'].str.contains("ankle")]
# 1262 rows
injuries = injuries[~injuries.Notes.str.contains("ankle")]

injuries[injuries['Notes'].str.contains("back")]
# 552 rows
injuries = injuries[~injuries.Notes.str.contains("back")]

injuries[injuries['Notes'].str.contains("foot")]
# 505 rows
injuries = injuries[~injuries.Notes.str.contains("foot")]

injuries[injuries['Notes'].str.contains("rest")]
# 470 rows
injuries = injuries[~injuries.Notes.str.contains("rest")]

injuries[injuries['Notes'].str.contains("hamstring")]
# 379 rows
injuries = injuries[~injuries.Notes.str.contains("hamstring")]

injuries[injuries['Notes'].str.contains("shoulder")]
# 314 rows
injuries = injuries[~injuries.Notes.str.contains("shoulder")]

injuries[injuries['Notes'].str.contains("illness")]
# 288 rows
injuries = injuries[~injuries.Notes.str.contains("illness")]

injuries[injuries['Notes'].str.contains("groin")]
# 246 rows
injuries = injuries[~injuries.Notes.str.contains("groin")]

injuries[injuries['Notes'].str.contains("calf")]
# 235 rows
injuries = injuries[~injuries.Notes.str.contains("calf")]

injuries[injuries['Notes'].str.contains("hip")]
# 223 rows
injuries = injuries[~injuries.Notes.str.contains("hip")]

injuries[injuries['Notes'].str.contains("hand")]
# 164 rows
injuries = injuries[~injuries.Notes.str.contains("hand")]

injuries[injuries['Notes'].str.contains("concussion")]
# 156 rows
injuries = injuries[~injuries.Notes.str.contains("concussion")]

injuries[injuries['Notes'].str.contains("wrist")]
# 150 rows
injuries = injuries[~injuries.Notes.str.contains("wrist")]

injuries[injuries['Notes'].str.contains("Achilles")]
# 134 rows
injuries = injuries[~injuries.Notes.str.contains("Achilles")]

injuries[injuries['Notes'].str.contains("Acchilles")]
# 1 rows
injuries = injuries[~injuries.Notes.str.contains("Acchilles")]

injuries[injuries['Notes'].str.contains("elbow")]
# 127 rows
injuries = injuries[~injuries.Notes.str.contains("elbow")]

injuries[injuries['Notes'].str.contains("toe")]
# 116 rows
injuries = injuries[~injuries.Notes.str.contains("toe")]

injuries[injuries['Notes'].str.contains("flu")]
# 113 rows
injuries = injuries[~injuries.Notes.str.contains("flu")]

injuries[injuries['Notes'].str.contains("quad")]
# 99 rows
injuries = injuries[~injuries.Notes.str.contains("quad")]

injuries[injuries['Notes'].str.contains("thumb")]
# 90 rows
injuries = injuries[~injuries.Notes.str.contains("thumb")]

injuries[injuries['Notes'].str.contains("leg")]
# 82 rows
injuries = injuries[~injuries.Notes.str.contains("leg")]

injuries[injuries['Notes'] == "DNP"]
# 72 rows
injuries = injuries[injuries['Notes'] != "DNP"]

injuries[injuries['Notes'] == "DNP (P)"]
# 8 rows
injuries = injuries[injuries['Notes'] != "DNP (P)"]

injuries[injuries['Notes'].str.contains("thigh")]
# 72 rows
injuries = injuries[~injuries.Notes.str.contains("thigh")]

injuries[injuries['Notes'].str.contains("finger")]
# 65 rows
injuries = injuries[~injuries.Notes.str.contains("finger")]

injuries[injuries['Notes'].str.contains("rib")]
# 52 rows
injuries = injuries[~injuries.Notes.str.contains("rib")]

injuries[injuries['Notes'].str.contains("neck")]
# 49 rows
injuries = injuries[~injuries.Notes.str.contains("neck")]

injuries[injuries['Notes'].str.contains("eye")]
# 48 rows
injuries = injuries[~injuries.Notes.str.contains("eye")]

injuries[injuries['Notes'].str.contains("abdomin")]
# 57 rows
injuries = injuries[~injuries.Notes.str.contains("abdomin")]

injuries[injuries['Notes'].str.contains("infection")]
# 45 rows
injuries = injuries[~injuries.Notes.str.contains("infection")]

injuries[injuries['Notes'].str.contains("stomach")]
# 42 rows
injuries = injuries[~injuries.Notes.str.contains("stomach")]

injuries[injuries['Notes'].str.contains("heel")]
# 36 rows
injuries = injuries[~injuries.Notes.str.contains("heel")]

injuries[injuries['Notes'].str.contains("shin")]
# 31 rows THEY ARE INCLUDING 1 INCCIDENT WHERE JOKIM NOAH PUSHED A FAN
injuries = injuries[~injuries.Notes.str.contains("shin")]

injuries[injuries['Notes'].str.contains("adductor")]
# 25 rows
injuries = injuries[~injuries.Notes.str.contains("adductor")]

injuries[injuries['Notes'].str.contains("head")]
# 25 rows
injuries = injuries[~injuries.Notes.str.contains("head")]

injuries[injuries['Notes'].str.contains("gastroenteritis")]
# 20 rows
injuries = injuries[~injuries.Notes.str.contains("gastroenteritis")]

injuries[injuries['Notes'].str.contains("undisclosed")]
# 18 rows
injuries = injuries[~injuries.Notes.str.contains("undisclosed")]

injuries[injuries['Notes'].str.contains("nose")]
# 18 rows
injuries = injuries[~injuries.Notes.str.contains("nose")]

injuries[injuries['Notes'].str.contains("food poisoning")]
# 14 rows
injuries = injuries[~injuries.Notes.str.contains("food poisoning")]

injuries[injuries['Notes'].str.contains("tibia")]
# 13 rows
injuries = injuries[~injuries.Notes.str.contains("tibia")]

injuries[injuries['Notes'].str.contains("vertigo")]
# 12 rows
injuries = injuries[~injuries.Notes.str.contains("vertigo")]

injuries[injuries['Notes'].str.contains("irritation")]
# 11 rows
injuries = injuries[~injuries.Notes.str.contains("irritation")]

injuries[injuries['Notes'].str.contains("abductor")]
# 11 rows
injuries = injuries[~injuries.Notes.str.contains("abductor")]

injuries[injuries['Notes'].str.contains("pelvis")]
# 7 rows
injuries = injuries[~injuries.Notes.str.contains("pelvis")]

injuries[injuries['Notes'].str.contains("patella tendon")]
# 5 rows
injuries = injuries[~injuries.Notes.str.contains("patella tendon")]

injuries[injuries['Notes'].str.contains("abdomen")]
# 4 rows
injuries = injuries[~injuries.Notes.str.contains("abdomen")]

injuries[injuries['Notes'].str.contains("fibula")]
# 4 rows
injuries = injuries[~injuries.Notes.str.contains("fibula")]

injuries[injuries['Notes'].str.contains("jaw")]
# 2 rows
injuries = injuries[~injuries.Notes.str.contains("jaw")]

injuries[injuries['Notes'].str.contains("cold")]
# 2 rows
injuries = injuries[~injuries.Notes.str.contains("cold")]

# %%
# Not going to look further because the counts are so low
# injuries.sort_values(by='Notes')
# injuries['Notes'].value_counts()

# %%
injuries
# Out:
#            Date          Team                                  Relinquised  \
# 71   2010-11-17          Jazz                               Kyrylo Fesenko
# 232  2010-12-31     Cavaliers                             Anderson Varejao
# 255  2011-01-04     Grizzlies                                    O.J. Mayo
# 258  2011-01-05         76ers                                  Tony Battie
# 273  2011-01-08         Bucks                                 Andrew Bogut
# 406  2011-02-05       Blazers                             Dante Cunningham
# 411  2011-02-06       Celtics                              Marquis Daniels
# 506  2011-03-01       Pistons                              Tayshaun Prince
# 559  2011-03-13          Suns                                   Steve Nash
# 564  2011-03-14          Suns                                   Steve Nash
# 630  2011-03-28         Spurs                        (William) Tony Parker
# ...
